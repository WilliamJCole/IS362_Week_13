# %% [markdown]
# # IS 362 Week 13 Assignment: Mushrooms!
#
# ### By Billy Cole
#
# So the assigment asks us to mushroom data into a data frame, add columns, alter the codes to a more useful number raiting and then anaylize the data.
#
# ##### First lets import the necesary libraries:

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
# %matplotlib inline
from sklearn.linear_model import LinearRegression

# %% [markdown]
# ##### Now let's put the data in a data frame and add some columns:

# %%
shrooms = pd.read_csv('https://archive.ics.uci.edu/ml/machine-learning-databases/mushroom/agaricus-lepiota.data',sep=',', header=None, usecols=[0,2,5,22], names=["Edible","Cap Color","Odor","Location"])
shrooms
# Out:
#      Edible Cap Color Odor Location
# 0         p         s    p        u
# 1         e         s    a        g
# 2         e         s    l        m
# 3         p         y    p        u
# 4         e         s    n        g
# 5         e         y    a        g
# 6         e         s    a        m
# 7         e         y    l        m
# 8         p         y    p        g
# 9         e         s    a        m
# 10        e         y    l        g
# 11        e         y    a        m
# 12        e         s    a        g
# 13        p         y    p        u
# 14        e         f    n        g
# 15        e         f    n        u
# 16        e         f    n        g
# 17        p         s    p        g
# 18        p         y    p        u
# 19        p         s    p        u
# 20        e         s    a        m
# 21        p         y    p        g
# 22        e         y    l        m
# 23        e         y    a        m
# 24        e         s    l        m
# 25        p         s    p        g
# 26        e         y    a        m
# 27        e         y    l        m
# 28        e         f    n        u
# 29        e         s    a        d
# ...     ...       ...  ...      ...
# 8094      e         s    n        g
# 8095      p         y    m        d
# 8096      e         f    n        g
# 8097      p         y    s        l
# 8098      p         s    y        d
# 8099      e         f    n        g
# 8100      e         s    n        l
# 8101      p         s    s        p
# 8102      e         s    n        l
# 8103      e         s    n        l
# 8104      e         s    n        l
# 8105      e         s    n        l
# 8106      e         s    n        l
# 8107      e         s    n        l
# 8108      p         y    y        l
# 8109      e         s    n        g
# 8110      e         s    n        l
# 8111      e         s    n        g
# 8112      e         s    n        l
# 8113      p         y    y        d
# 8114      p         y    m        d
# 8115      e         s    n        l
# 8116      p         y    s        l
# 8117      p         s    y        d
# 8118      p         y    f        d
# 8119      e         s    n        l
# 8120      e         s    n        l
# 8121      e         s    n        l
# 8122      p         y    y        l
# 8123      e         s    n        l
#
# [8124 rows x 4 columns]

# %% [markdown]
# ##### Now let's change the codes to a more useful numerical data.
#
# 1 = poison
# 0 = Edible

# %%
shrooms.replace(to_replace={"Edible":{'p': 1, 'e': 0}}, inplace=True)

# %%
shrooms
# Out:
#       Edible Cap Color Odor Location
# 0          1         s    p        u
# 1          0         s    a        g
# 2          0         s    l        m
# 3          1         y    p        u
# 4          0         s    n        g
# 5          0         y    a        g
# 6          0         s    a        m
# 7          0         y    l        m
# 8          1         y    p        g
# 9          0         s    a        m
# 10         0         y    l        g
# 11         0         y    a        m
# 12         0         s    a        g
# 13         1         y    p        u
# 14         0         f    n        g
# 15         0         f    n        u
# 16         0         f    n        g
# 17         1         s    p        g
# 18         1         y    p        u
# 19         1         s    p        u
# 20         0         s    a        m
# 21         1         y    p        g
# 22         0         y    l        m
# 23         0         y    a        m
# 24         0         s    l        m
# 25         1         s    p        g
# 26         0         y    a        m
# 27         0         y    l        m
# 28         0         f    n        u
# 29         0         s    a        d
# ...      ...       ...  ...      ...
# 8094       0         s    n        g
# 8095       1         y    m        d
# 8096       0         f    n        g
# 8097       1         y    s        l
# 8098       1         s    y        d
# 8099       0         f    n        g
# 8100       0         s    n        l
# 8101       1         s    s        p
# 8102       0         s    n        l
# 8103       0         s    n        l
# 8104       0         s    n        l
# 8105       0         s    n        l
# 8106       0         s    n        l
# 8107       0         s    n        l
# 8108       1         y    y        l
# 8109       0         s    n        g
# 8110       0         s    n        l
# 8111       0         s    n        g
# 8112       0         s    n        l
# 8113       1         y    y        d
# 8114       1         y    m        d
# 8115       0         s    n        l
# 8116       1         y    s        l
# 8117       1         s    y        d
# 8118       1         y    f        d
# 8119       0         s    n        l
# 8120       0         s    n        l
# 8121       0         s    n        l
# 8122       1         y    y        l
# 8123       0         s    n        l
#
# [8124 rows x 4 columns]

# %% [markdown]
# ##### Now for some analysis
