# %% [markdown]
# # IS 362 Week 13 Assignment: Mushrooms!
#
# ### By Billy Cole
#
# So. the assignment asks us to mushroom data into a data frame, add columns, alter the codes to a more useful number rating and then analyze the data.
#
# ##### First let’s import the necessary libraries:

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
# %matplotlib inline
from sklearn.linear_model import LinearRegression

# %% [markdown]
# ##### Now let's put the data in a data frame and add some columns:

# %%
shrooms = pd.read_csv('https://archive.ics.uci.edu/ml/machine-learning-databases/mushroom/agaricus-lepiota.data',sep=',', header=None, usecols=[0,3,5], names=["Edible","Color","Odor"])
shrooms
# Out:
#      Edible Color Odor
# 0         p     n    p
# 1         e     y    a
# 2         e     w    l
# 3         p     w    p
# 4         e     g    n
# 5         e     y    a
# 6         e     w    a
# 7         e     w    l
# 8         p     w    p
# 9         e     y    a
# 10        e     y    l
# 11        e     y    a
# 12        e     y    a
# 13        p     w    p
# 14        e     n    n
# 15        e     g    n
# 16        e     w    n
# 17        p     n    p
# 18        p     w    p
# 19        p     n    p
# 20        e     y    a
# 21        p     n    p
# 22        e     y    l
# 23        e     w    a
# 24        e     w    l
# 25        p     w    p
# 26        e     y    a
# 27        e     w    l
# 28        e     n    n
# 29        e     y    a
# ...     ...   ...  ...
# 8094      e     g    n
# 8095      p     c    m
# 8096      e     w    n
# 8097      p     n    s
# 8098      p     e    y
# 8099      e     w    n
# 8100      e     n    n
# 8101      p     e    s
# ...

# %% [markdown]
# ##### Now let's change the codes to a more useful numerical data.
#
# Edible:
#
# Poisonous = p = 1
# Edible = e = 0
#
# Color:
#
# brown = n = 0
# buff = b = 1
# cinnamon = c = 2
# gray = g = 3
# green = r = 4
# pink = p = 5
# purple = u = 6
# red = e = 7
# white = w = 8
# yellow = y = 9
#
# Odor:
# almond = a = 0
# anise = l = 1
# creosote = c = 2
# fishy = y = 3
# foul = f = 4
# musty = m = 5
# none = n = 6
# pungent = p = 7
# spicy = s = 8

# %%
shrooms.replace(to_replace={"Edible":{'p': 1, 'e': 0}}, inplace=True)
shrooms.replace(to_replace={'Color':{'n':0, 'b':1, 'c':2, 'g':3, 'r':4, 'p':5, 'u':6, 'e':7, 'w':8, 'y':9}}, inplace=True)
shrooms.replace(to_replace={'Odor':{'a':0, 'l':1, 'c':2, 'y':3, 'f':4, 'm':5, 'n':6, 'p':7, 's':8}}, inplace=True)

# %%
shrooms
# Out:
#       Edible  Color  Odor
# 0          1      0     7
# 1          0      9     0
# 2          0      8     1
# 3          1      8     7
# 4          0      3     6
# 5          0      9     0
# 6          0      8     0
# 7          0      8     1
# 8          1      8     7
# 9          0      9     0
# 10         0      9     1
# 11         0      9     0
# 12         0      9     0
# 13         1      8     7
# 14         0      0     6
# 15         0      3     6
# 16         0      8     6
# 17         1      0     7
# 18         1      8     7
# 19         1      0     7
# 20         0      9     0
# 21         1      0     7
# 22         0      9     1
# 23         0      8     0
# 24         0      8     1
# 25         1      8     7
# 26         0      9     0
# 27         0      8     1
# 28         0      0     6
# 29         0      9     0
# ...      ...    ...   ...
# 8094       0      3     6
# 8095       1      2     5
# 8096       0      8     6
# ...

# %% [markdown]
# ##### Now for some analysis

# %%
sns.set(style="ticks", context="talk")
pal = sns.color_palette("hls", 8)
g = sns.lmplot(x='Odor', y='Color', hue='Edible', data=shrooms, palette=pal, size=7)
g.set_axis_labels("Odor", "Color")
sns.plt.show()

# %% [markdown]
# So, as the graph shows, if the mushroom has either an almond or anise scent it is ok to eat. Most other mushrooms will **kill** you, except for mushrooms with no odor and the colors of cinnamon, grey, green, purple and red.
